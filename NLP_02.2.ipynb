# %% [markdown]
# # NLP-02 — Text Preprocessing

# %%
import nltk

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import re
import pandas as pd
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

# %%
documents = [
    "Natural language processing is transforming Artificial Intelligence.",
    "Machine learning model require clean and normalized text data.",
    "Tokenization, stemming, and lemmatization are important NLP preprocessing step."
]

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
stemmer = PorterStemmer()
lemmatizer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def preprocess_text(text):
    # Normalization
    text = text.lower()
    text = re.sub(r'[^a-z\s]', '', text)

    # Tokenization
    tokens = word_tokenize(text)

    # Stop-word removal
    filtered_tokens = [word for word in tokens if word not in stop_words]

    # Stemming
    stemmed_tokens = [stemmer.stem(word) for word in filtered_tokens]

    # Lemmatization
    lemmatized_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]

    return {
        'Original_Text': text,
        'Tokens': tokens,
        'After_Stopword_Removal': filtered_tokens,
        'Stemmed': stemmed_tokens,
        'Lemmatized': lemmatized_tokens
    }

# %%
nltk.download('punkt_tab')
result = [preprocess_text(doc) for doc in documents]
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.

# %%
df = pd.DataFrame(result)
df
# Out:
#                                        Original_Text  \
# 0  natural language processing is transforming ar...
# 1  machine learning model require clean and norma...
# 2  tokenization stemming and lemmatization are im...
#
#                                               Tokens  \
# 0  [natural, language, processing, is, transformi...
# 1  [machine, learning, model, require, clean, and...
# 2  [tokenization, stemming, and, lemmatization, a...
#
#                               After_Stopword_Removal  \
# 0  [natural, language, processing, transforming, ...
# 1  [machine, learning, model, require, clean, nor...
# 2  [tokenization, stemming, lemmatization, import...
#
#                                              Stemmed  \
# 0  [natur, languag, process, transform, artifici,...
# 1  [machin, learn, model, requir, clean, normal, ...
# 2  [token, stem, lemmat, import, nlp, preprocess,...
#
#                                           Lemmatized
# ...
